# %%
import numpy as np
from scipy.stats import norm
import sklearn
from sklearn.datasets.samples_generator import make_blobs
import pandas as pd

# %%
np.random.seed(2)

# %%
x, y = make_blobs(n_samples=1000,n_features=2,centers=1)

# %%
x.shape
# Out:
# (1000, 2)

# %%
y.shape
# Out:
# (1000,)

# %%
print(type(x))
print(type(y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
## easy function avaliable in sklearn
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()

model.fit(x,y)

xtest = [x[0]]
ytest = y[0]

predict = model.predict(xtest)

xprob = model.predict_proba(xtest)

print("Predictied probabilites ",xprob)

print("Actual value ",ytest)
print("Predicted value ",predict)
# Out:
# Predictied probabilites  [[1.]]
# Actual value  0
# Predicted value  [0]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.plot(x)
# Out:
# [<matplotlib.lines.Line2D at 0x13431f91940>,
#  <matplotlib.lines.Line2D at 0x13431f91a90>]

# %%
## lets create our own classifier

def probability_distribution(data):
    mu = np.mean(data)
    std = np.std(data)
    print(mu,std)
    dist = np.norm(mu,std)
    print(dist)
    return dist

# %%
def independent_conditional_probability(x,prior_prob,dist1,dist2):
    return prior_prob * dist1.pdf(x[0]) * dist2.pdf(x[1])

# %%
## here we sort our classes 
xy0 = x[y==0]
xy1 = x[y==1]
